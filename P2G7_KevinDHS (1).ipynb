# %% [markdown]
# # I.PERKENALAN
#
# Name : Kevin David Hizkia Simangunsong
#
# Batch: BSD_004
#
# Dataset :
#
# Problem Statement :

# %% [markdown]
# # II.IMPORT LIBRARY

# %%
# acces folder
import os
import glob
import random

# data loading
import numpy as np
import pandas as pd
import cv2

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing and Models
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, Input
from sklearn.model_selection import train_test_split

# Model Evaluation
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score,classification_report,ConfusionMatrixDisplay,confusion_matrix
import warnings

import pdb
# transfer learning
import tensorflow_hub as hub
warnings.filterwarnings('ignore')

# %%
np.set_printoptions(suppress=True)

# %%
# connect to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # III.DATA LOADING

# %%
# create kaggle directory
# !mkdir ~/.kaggle

# %%
pip install kaggle

# %%
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle

# %%
# !kaggle datasets download -d kritikseth/fruit-and-vegetable-image-recognition
# Out:
# ...
#  99% 1.97G/1.98G [00:15<00:00, 246MB/s]
# 100% 1.98G/1.98G [00:15<00:00, 136MB/s]

# %%
# !kaggle datasets download -d kritikseth/fruit-and-vegetable-image-recognition --force

# %%
# !unzip -q /content/fruit-and-vegetable-image-recognition.zip -d images

# %%
main_path = '/content/images'
os.listdir(main_path)
# Out:
# ['train', 'test', 'validation']

# %%
# create variable for train, test, validation directory
train_dir = os.path.join(main_path, 'train')
test_dir = os.path.join(main_path, 'test')
val_dir = os.path.join(main_path, 'validation')
print(train_dir)
print(test_dir)
print(val_dir)
# Out:
# /content/images/train
# /content/images/test
# /content/images/validation

# %%
# create class variable
# train class
train_Apple = len(os.listdir(os.path.join(train_dir, 'apple')))
train_Banana = len(os.listdir(os.path.join(train_dir, 'banana')))
train_Beetroot = len(os.listdir(os.path.join(train_dir, 'beetroot')))
train_Bell_Pepper = len(os.listdir(os.path.join(train_dir, 'bell pepper')))
train_Cabbage = len(os.listdir(os.path.join(train_dir, 'cabbage')))
train_Capsicum = len(os.listdir(os.path.join(train_dir, 'capsicum')))
train_Carrot = len(os.listdir(os.path.join(train_dir, 'carrot')))
train_Cauliflower = len(os.listdir(os.path.join(train_dir, 'cauliflower')))
train_Chilli_pepper = len(os.listdir(os.path.join(train_dir, 'chilli pepper')))
train_Corn = len(os.listdir(os.path.join(train_dir, 'corn')))
train_Cucumber = len(os.listdir(os.path.join(train_dir, 'cucumber')))
train_Eggplant = len(os.listdir(os.path.join(train_dir, 'eggplant')))
train_Garlic = len(os.listdir(os.path.join(train_dir, 'garlic')))
train_Ginger = len(os.listdir(os.path.join(train_dir, 'ginger')))
train_Grapes = len(os.listdir(os.path.join(train_dir, 'grapes')))
train_Jalepeno = len(os.listdir(os.path.join(train_dir, 'jalepeno')))
train_Kiwi = len(os.listdir(os.path.join(train_dir, 'kiwi')))
train_Lemon = len(os.listdir(os.path.join(train_dir, 'lemon')))
train_Lettuce = len(os.listdir(os.path.join(train_dir, 'lettuce')))
train_Mango = len(os.listdir(os.path.join(train_dir, 'mango')))
train_Onion = len(os.listdir(os.path.join(train_dir, 'onion')))
train_Orange = len(os.listdir(os.path.join(train_dir, 'orange')))
train_Paprika = len(os.listdir(os.path.join(train_dir, 'paprika')))
train_Pear = len(os.listdir(os.path.join(train_dir, 'pear')))
train_Peas = len(os.listdir(os.path.join(train_dir, 'peas')))
train_Pineapple = len(os.listdir(os.path.join(train_dir, 'pineapple')))
train_Pomegranate = len(os.listdir(os.path.join(train_dir, 'pomegranate')))
train_Potato = len(os.listdir(os.path.join(train_dir, 'potato')))
train_Raddish = len(os.listdir(os.path.join(train_dir, 'raddish')))
train_Soy_beans = len(os.listdir(os.path.join(train_dir, 'soy beans')))
train_Spinach = len(os.listdir(os.path.join(train_dir, 'spinach')))
train_Sweetcorn = len(os.listdir(os.path.join(train_dir, 'sweetcorn')))
train_Tomato = len(os.listdir(os.path.join(train_dir, 'tomato')))
train_Turnip = len(os.listdir(os.path.join(train_dir, 'turnip')))
train_Watermelon = len(os.listdir(os.path.join(train_dir, 'watermelon')))

# test
test_Apple = len(os.listdir(os.path.join(test_dir, 'apple')))
test_Banana = len(os.listdir(os.path.join(test_dir, 'banana')))
test_Beetroot = len(os.listdir(os.path.join(test_dir, 'beetroot')))
test_Bell_Pepper = len(os.listdir(os.path.join(test_dir, 'bell pepper')))
test_Cabbage = len(os.listdir(os.path.join(test_dir, 'cabbage')))
test_Capsicum = len(os.listdir(os.path.join(test_dir, 'capsicum')))
test_Carrot = len(os.listdir(os.path.join(test_dir, 'carrot')))
test_Cauliflower = len(os.listdir(os.path.join(test_dir, 'cauliflower')))
test_Chilli_pepper = len(os.listdir(os.path.join(test_dir, 'chilli pepper')))
test_Corn = len(os.listdir(os.path.join(test_dir, 'corn')))
test_Cucumber = len(os.listdir(os.path.join(test_dir, 'cucumber')))
test_Eggplant = len(os.listdir(os.path.join(test_dir, 'eggplant')))
test_Garlic = len(os.listdir(os.path.join(test_dir, 'garlic')))
test_Ginger = len(os.listdir(os.path.join(test_dir, 'ginger')))
test_Grapes = len(os.listdir(os.path.join(test_dir, 'grapes')))
test_Jalepeno = len(os.listdir(os.path.join(test_dir, 'jalepeno')))
test_Kiwi = len(os.listdir(os.path.join(test_dir, 'kiwi')))
test_Lemon = len(os.listdir(os.path.join(test_dir, 'lemon')))
test_Lettuce = len(os.listdir(os.path.join(test_dir, 'lettuce')))
test_Mango = len(os.listdir(os.path.join(test_dir, 'mango')))
test_Onion = len(os.listdir(os.path.join(test_dir, 'onion')))
test_Orange = len(os.listdir(os.path.join(test_dir, 'orange')))
test_Paprika = len(os.listdir(os.path.join(test_dir, 'paprika')))
test_Pear = len(os.listdir(os.path.join(test_dir, 'pear')))
test_Peas = len(os.listdir(os.path.join(test_dir, 'peas')))
test_Pineapple = len(os.listdir(os.path.join(test_dir, 'pineapple')))
test_Pomegranate = len(os.listdir(os.path.join(test_dir, 'pomegranate')))
test_Potato = len(os.listdir(os.path.join(test_dir, 'potato')))
test_Raddish = len(os.listdir(os.path.join(test_dir, 'raddish')))
test_Soy_beans = len(os.listdir(os.path.join(test_dir, 'soy beans')))
test_Spinach = len(os.listdir(os.path.join(test_dir, 'spinach')))
test_Sweetcorn = len(os.listdir(os.path.join(test_dir, 'sweetcorn')))
test_Tomato = len(os.listdir(os.path.join(test_dir, 'tomato')))
test_Turnip = len(os.listdir(os.path.join(test_dir, 'turnip')))
test_Watermelon = len(os.listdir(os.path.join(test_dir, 'watermelon')))

# Validation
val_Apple = len(os.listdir(os.path.join(val_dir, 'apple')))
val_Banana = len(os.listdir(os.path.join(val_dir, 'banana')))
val_Beetroot = len(os.listdir(os.path.join(val_dir, 'beetroot')))
val_Bell_Pepper = len(os.listdir(os.path.join(val_dir, 'bell pepper')))
val_Cabbage = len(os.listdir(os.path.join(val_dir, 'cabbage')))
val_Capsicum = len(os.listdir(os.path.join(val_dir, 'capsicum')))
val_Carrot = len(os.listdir(os.path.join(val_dir, 'carrot')))
val_Cauliflower = len(os.listdir(os.path.join(val_dir, 'cauliflower')))
val_Chilli_pepper = len(os.listdir(os.path.join(val_dir, 'chilli pepper')))
val_Corn = len(os.listdir(os.path.join(val_dir, 'corn')))
val_Cucumber = len(os.listdir(os.path.join(val_dir, 'cucumber')))
val_Eggplant = len(os.listdir(os.path.join(val_dir, 'eggplant')))
val_Garlic = len(os.listdir(os.path.join(val_dir, 'garlic')))
val_Ginger = len(os.listdir(os.path.join(val_dir, 'ginger')))
val_Grapes = len(os.listdir(os.path.join(val_dir, 'grapes')))
val_Jalepeno = len(os.listdir(os.path.join(val_dir, 'jalepeno')))
val_Kiwi = len(os.listdir(os.path.join(val_dir, 'kiwi')))
val_Lemon = len(os.listdir(os.path.join(val_dir, 'lemon')))
val_Lettuce = len(os.listdir(os.path.join(val_dir, 'lettuce')))
val_Mango = len(os.listdir(os.path.join(val_dir, 'mango')))
val_Onion = len(os.listdir(os.path.join(val_dir, 'onion')))
val_Orange = len(os.listdir(os.path.join(val_dir, 'orange')))
val_Paprika = len(os.listdir(os.path.join(val_dir, 'paprika')))
val_Pear = len(os.listdir(os.path.join(val_dir, 'pear')))
val_Peas = len(os.listdir(os.path.join(val_dir, 'peas')))
val_Pineapple = len(os.listdir(os.path.join(val_dir, 'pineapple')))
val_Pomegranate = len(os.listdir(os.path.join(val_dir, 'pomegranate')))
val_Potato = len(os.listdir(os.path.join(val_dir, 'potato')))
val_Raddish = len(os.listdir(os.path.join(val_dir, 'raddish')))
val_Soy_beans = len(os.listdir(os.path.join(val_dir, 'soy beans')))
val_Spinach = len(os.listdir(os.path.join(val_dir, 'spinach')))
val_Sweetcorn = len(os.listdir(os.path.join(val_dir, 'sweetcorn')))
val_Tomato = len(os.listdir(os.path.join(val_dir, 'tomato')))
val_Turnip = len(os.listdir(os.path.join(val_dir, 'turnip')))
val_Watermelon = len(os.listdir(os.path.join(val_dir, 'watermelon')))

# %%
# data count

print('Train Dataset')
print('Total Data of train_Apple : ', train_Apple)
print('Total Data of train_Banana : ', train_Banana)
print('Total Data of train_Beetroot : ', train_Beetroot)
print('Total Data of train_Bell_Pepper : ', train_Bell_Pepper)
print('Total Data of train_Cabbage : ', train_Cabbage)
print('Total Data of train_Capsicum : ', train_Capsicum)
print('Total Data of train_Carrot : ', train_Carrot)
print('Total Data of train_Cauliflower : ', train_Cauliflower)
print('Total Data of train_Chilli_Pepper : ', train_Chilli_pepper)
print('Total Data of train_Corn : ', train_Corn)
print('Total Data of train_Cucumber : ', train_Cucumber)
print('Total Data of train_Eggplant : ', train_Eggplant)
print('Total Data of train_Garlic : ', train_Garlic)
print('Total Data of train_Ginger : ', train_Ginger)
print('Total Data of train_Grapes : ', train_Grapes)
print('Total Data of train_Jalepeno : ', train_Jalepeno)
print('Total Data of train_Kiwi : ', train_Kiwi)
print('Total Data of train_Lemon : ', train_Lemon)
print('Total Data of train_Lettuce : ', train_Lettuce)
print('Total Data of train_Mango : ', train_Mango)
print('Total Data of train_Onion : ', train_Onion)
print('Total Data of train_Orange : ', train_Orange)
print('Total Data of train_Paprika : ', train_Paprika)
print('Total Data of train_Pear : ', train_Pear)
print('Total Data of train_Peas : ', train_Peas)
print('Total Data of train_Pineapple : ', train_Pineapple)
print('Total Data of train_Pomegranate : ', train_Pomegranate)
print('Total Data of train_Potato : ', train_Potato)
print('Total Data of train_Raddish : ', train_Raddish)
print('Total Data of train_Soy_Beans : ', train_Soy_beans)
print('Total Data of train_Spinach : ', train_Spinach)
print('Total Data of train_Sweetcorn : ', train_Sweetcorn)
print('Total Data of train_Tomato : ', train_Tomato)
print('Total Data of train_Turnip : ', train_Turnip)
print('Total Data of train_Watermelon : ', train_Watermelon)
# Out:
# Train Dataset
# Total Data of train_Apple :  68
# Total Data of train_Banana :  75
# Total Data of train_Beetroot :  88
# Total Data of train_Bell_Pepper :  90
# Total Data of train_Cabbage :  92
# Total Data of train_Capsicum :  89
# Total Data of train_Carrot :  82
# Total Data of train_Cauliflower :  79
# Total Data of train_Chilli_Pepper :  87
# Total Data of train_Corn :  87
# Total Data of train_Cucumber :  94
# Total Data of train_Eggplant :  84
# Total Data of train_Garlic :  92
# Total Data of train_Ginger :  68
# Total Data of train_Grapes :  100
# Total Data of train_Jalepeno :  88
# Total Data of train_Kiwi :  88
# Total Data of train_Lemon :  82
# Total Data of train_Lettuce :  97
# Total Data of train_Mango :  86
# Total Data of train_Onion :  94
# Total Data of train_Orange :  69
# Total Data of train_Paprika :  83
# Total Data of train_Pear :  89
# Total Data of train_Peas :  100
# Total Data of train_Pineapple :  99
# Total Data of train_Pomegranate :  79
# ...

# %%
# data count Test

print('test Dataset')
print('Total Data of test_Apple : ', test_Apple)
print('Total Data of test_Banana : ', test_Banana)
print('Total Data of test_Beetroot : ', test_Beetroot)
print('Total Data of test_Bell_Pepper : ', test_Bell_Pepper)
print('Total Data of test_Cabbage : ', test_Cabbage)
print('Total Data of test_Capsicum : ', test_Capsicum)
print('Total Data of test_Carrot : ', test_Carrot)
print('Total Data of test_Cauliflower : ', test_Cauliflower)
print('Total Data of test_Chilli_Pepper : ', test_Chilli_pepper)
print('Total Data of test_Corn : ', test_Corn)
print('Total Data of test_Cucumber : ', test_Cucumber)
print('Total Data of test_Eggplant : ', test_Eggplant)
print('Total Data of test_Garlic : ', test_Garlic)
print('Total Data of test_Ginger : ', test_Ginger)
print('Total Data of test_Grapes : ', test_Grapes)
print('Total Data of test_Jalepeno : ', test_Jalepeno)
print('Total Data of test_Kiwi : ', test_Kiwi)
print('Total Data of test_Lemon : ', test_Lemon)
print('Total Data of test_Lettuce : ', test_Lettuce)
print('Total Data of test_Mango : ', test_Mango)
print('Total Data of test_Onion : ', test_Onion)
print('Total Data of test_Orange : ', test_Orange)
print('Total Data of test_Paprika : ', test_Paprika)
print('Total Data of test_Pear : ', test_Pear)
print('Total Data of test_Peas : ', test_Peas)
print('Total Data of test_Pineapple : ', test_Pineapple)
print('Total Data of test_Pomegranate : ', test_Pomegranate)
print('Total Data of test_Potato : ', test_Potato)
print('Total Data of test_Raddish : ', test_Raddish)
print('Total Data of test_Soy_Beans : ', test_Soy_beans)
print('Total Data of test_Spinach : ', test_Spinach)
print('Total Data of test_Sweetcorn : ', test_Sweetcorn)
print('Total Data of test_Tomato : ', test_Tomato)
print('Total Data of test_Turnip : ', test_Turnip)
print('Total Data of test_Watermelon : ', test_Watermelon)
# Out:
# test Dataset
# Total Data of test_Apple :  10
# Total Data of test_Banana :  9
# Total Data of test_Beetroot :  10
# Total Data of test_Bell_Pepper :  10
# Total Data of test_Cabbage :  10
# Total Data of test_Capsicum :  10
# Total Data of test_Carrot :  10
# Total Data of test_Cauliflower :  10
# Total Data of test_Chilli_Pepper :  10
# Total Data of test_Corn :  10
# Total Data of test_Cucumber :  10
# Total Data of test_Eggplant :  10
# Total Data of test_Garlic :  10
# Total Data of test_Ginger :  10
# Total Data of test_Grapes :  10
# Total Data of test_Jalepeno :  10
# Total Data of test_Kiwi :  10
# Total Data of test_Lemon :  10
# Total Data of test_Lettuce :  10
# Total Data of test_Mango :  10
# Total Data of test_Onion :  10
# Total Data of test_Orange :  10
# Total Data of test_Paprika :  10
# Total Data of test_Pear :  10
# Total Data of test_Peas :  10
# Total Data of test_Pineapple :  10
# Total Data of test_Pomegranate :  10
# Total Data of test_Potato :  10
# ...

# %%
# data count val

print('val Dataset')
print('Total Data of val_Apple : ', val_Apple)
print('Total Data of val_Banana : ', val_Banana)
print('Total Data of val_Beetroot : ', val_Beetroot)
print('Total Data of val_Bell_Pepper : ', val_Bell_Pepper)
print('Total Data of val_Cabbage : ', val_Cabbage)
print('Total Data of val_Capsicum : ', val_Capsicum)
print('Total Data of val_Carrot : ', val_Carrot)
print('Total Data of val_Cauliflower : ', val_Cauliflower)
print('Total Data of val_Chilli_Pepper : ', val_Chilli_pepper)
print('Total Data of val_Corn : ', val_Corn)
print('Total Data of val_Cucumber : ', val_Cucumber)
print('Total Data of val_Eggplant : ', val_Eggplant)
print('Total Data of val_Garlic : ', val_Garlic)
print('Total Data of val_Ginger : ', val_Ginger)
print('Total Data of val_Grapes : ', val_Grapes)
print('Total Data of val_Jalepeno : ', val_Jalepeno)
print('Total Data of val_Kiwi : ', val_Kiwi)
print('Total Data of val_Lemon : ', val_Lemon)
print('Total Data of val_Lettuce : ', val_Lettuce)
print('Total Data of val_Mango : ', val_Mango)
print('Total Data of val_Onion : ', val_Onion)
print('Total Data of val_Orange : ', val_Orange)
print('Total Data of val_Paprika : ', val_Paprika)
print('Total Data of val_Pear : ', val_Pear)
print('Total Data of val_Peas : ', val_Peas)
print('Total Data of val_Pineapple : ', val_Pineapple)
print('Total Data of val_Pomegranate : ', val_Pomegranate)
print('Total Data of val_Potato : ', val_Potato)
print('Total Data of val_Raddish : ', val_Raddish)
print('Total Data of val_Soy_Beans : ', val_Soy_beans)
print('Total Data of val_Spinach : ', val_Spinach)
print('Total Data of val_Sweetcorn : ', val_Sweetcorn)
print('Total Data of val_Tomato : ', val_Tomato)
print('Total Data of val_Turnip : ', val_Turnip)
print('Total Data of val_Watermelon : ', val_Watermelon)
# Out:
# val Dataset
# Total Data of val_Apple :  10
# Total Data of val_Banana :  9
# Total Data of val_Beetroot :  10
# Total Data of val_Bell_Pepper :  9
# Total Data of val_Cabbage :  10
# Total Data of val_Capsicum :  10
# Total Data of val_Carrot :  9
# Total Data of val_Cauliflower :  10
# Total Data of val_Chilli_Pepper :  9
# Total Data of val_Corn :  10
# Total Data of val_Cucumber :  10
# Total Data of val_Eggplant :  10
# Total Data of val_Garlic :  10
# Total Data of val_Ginger :  10
# Total Data of val_Grapes :  9
# Total Data of val_Jalepeno :  9
# Total Data of val_Kiwi :  10
# Total Data of val_Lemon :  10
# Total Data of val_Lettuce :  9
# Total Data of val_Mango :  10
# Total Data of val_Onion :  10
# Total Data of val_Orange :  9
# Total Data of val_Paprika :  10
# Total Data of val_Pear :  10
# Total Data of val_Peas :  10
# Total Data of val_Pineapple :  10
# Total Data of val_Pomegranate :  10
# Total Data of val_Potato :  10
# Total Data of val_Raddish :  9
# ...

# %%
# Create a variable from filepaths

#train

train_Apple= glob.glob(train_dir + '/apple/*.jpg')
train_Banana= glob.glob(train_dir + '/banana/*.jpg')
train_Beetroot= glob.glob(train_dir + '/beetroot/*.jpg')
train_Bell_Pepper= glob.glob(train_dir + '/bell pepper/*.jpg')
train_Cabbage= glob.glob(train_dir + '/cabbage/*.jpg')
train_Capsicum= glob.glob(train_dir + '/capsicum/*.jpg')
train_Carrot= glob.glob(train_dir + '/carrot/*.jpg')
train_Cauliflower= glob.glob(train_dir + '/cauliflower/*.jpg')
train_Chilli_pepper= glob.glob(train_dir + '/chilli pepper/*.jpg')
train_Corn= glob.glob(train_dir + '/corn/*.jpg')
train_Cucumber= glob.glob(train_dir + '/cucumber/*.jpg')
train_Eggplant= glob.glob(train_dir + '/eggplant/*.jpg')
train_Garlic= glob.glob(train_dir + '/garlic/*.jpg')
train_Ginger= glob.glob(train_dir + '/ginger/*.jpg')
train_Grapes= glob.glob(train_dir + '/grapes/*.jpg')
train_Jalepeno= glob.glob(train_dir + '/jalepeno/*.jpg')
train_Kiwi= glob.glob(train_dir + '/kiwi/*.jpg')
train_Lemon= glob.glob(train_dir + '/lemon/*.jpg')
train_Lettuce= glob.glob(train_dir + '/lettuce/*.jpg')
train_Mango= glob.glob(train_dir + '/mango/*.jpg')
train_Onion= glob.glob(train_dir + '/onion/*.jpg')
train_Orange= glob.glob(train_dir + '/orange/*.jpg')
train_Paprika= glob.glob(train_dir + '/paprika/*.jpg')
train_Pear= glob.glob(train_dir + '/pear/*.jpg')
train_Peas= glob.glob(train_dir + '/peas/*.jpg')
train_Pineapple= glob.glob(train_dir + '/pineapple/*.jpg')
train_Pomegranate= glob.glob(train_dir + '/pomegranate/*.jpg')
train_Potato= glob.glob(train_dir + '/potato/*.jpg')
train_Raddish= glob.glob(train_dir + '/raddish/*.jpg')
train_Soy_beans= glob.glob(train_dir + '/soy beans/*.jpg')
train_Spinach= glob.glob(train_dir + '/spinach/*.jpg')
train_Sweetcorn= glob.glob(train_dir + '/sweetcorn/*.jpg')
train_Tomato= glob.glob(train_dir + '/tomato/*.jpg')
train_Turnip= glob.glob(train_dir + '/turnip/*.jpg')
train_Watermelon= glob.glob(train_dir + '/Watermelon/*.jpg')

# %%
# Create a variable from filepaths

#test

test_Apple= glob.glob(test_dir + '/apple/*.jpg')
test_Banana= glob.glob(test_dir + '/banana/*.jpg')
test_Beetroot= glob.glob(test_dir + '/beetroot/*.jpg')
test_Bell_Pepper= glob.glob(test_dir + '/bell pepper/*.jpg')
test_Cabbage= glob.glob(test_dir + '/cabbage/*.jpg')
test_Capsicum= glob.glob(test_dir + '/capsicum/*.jpg')
test_Carrot= glob.glob(test_dir + '/carrot/*.jpg')
test_Cauliflower= glob.glob(test_dir + '/cauliflower/*.jpg')
test_Chilli_pepper= glob.glob(test_dir + '/chilli pepper/*.jpg')
test_Corn= glob.glob(test_dir + '/corn/*.jpg')
test_Cucumber= glob.glob(test_dir + '/cucumber/*.jpg')
test_Eggplant= glob.glob(test_dir + '/eggplant/*.jpg')
test_Garlic= glob.glob(test_dir + '/garlic/*.jpg')
test_Ginger= glob.glob(test_dir + '/ginger/*.jpg')
test_Grapes= glob.glob(test_dir + '/grapes/*.jpg')
test_Jalepeno= glob.glob(test_dir + '/jalepeno/*.jpg')
test_Kiwi= glob.glob(test_dir + '/kiwi/*.jpg')
test_Lemon= glob.glob(test_dir + '/lemon/*.jpg')
test_Lettuce= glob.glob(test_dir + '/lettuce/*.jpg')
test_Mango= glob.glob(test_dir + '/mango/*.jpg')
test_Onion= glob.glob(test_dir + '/onion/*.jpg')
test_Orange= glob.glob(test_dir + '/orange/*.jpg')
test_Paprika= glob.glob(test_dir + '/paprika/*.jpg')
test_Pear= glob.glob(test_dir + '/pear/*.jpg')
test_Peas= glob.glob(test_dir + '/peas/*.jpg')
test_Pineapple= glob.glob(test_dir + '/pineapple/*.jpg')
test_Pomegranate= glob.glob(test_dir + '/pomegranate/*.jpg')
test_Potato= glob.glob(test_dir + '/potato/*.jpg')
test_Raddish= glob.glob(test_dir + '/raddish/*.jpg')
test_Soy_beans= glob.glob(test_dir + '/soy beans/*.jpg')
test_Spinach= glob.glob(test_dir + '/spinach/*.jpg')
test_Sweetcorn= glob.glob(test_dir + '/sweetcorn/*.jpg')
test_Tomato= glob.glob(test_dir + '/tomato/*.jpg')
test_Turnip= glob.glob(test_dir + '/turnip/*.jpg')
test_Watermelon= glob.glob(test_dir + '/Watermelon/*.jpg')

# %%
# Create a variable from filepaths

# validation

val_Apple= glob.glob(val_dir + '/apple/*.jpg')
val_Banana= glob.glob(val_dir + '/banana/*.jpg')
val_Beetroot= glob.glob(val_dir + '/beetroot/*.jpg')
val_Bell_Pepper= glob.glob(val_dir + '/bell pepper/*.jpg')
val_Cabbage= glob.glob(val_dir + '/cabbage/*.jpg')
val_Capsicum= glob.glob(val_dir + '/capsicum/*.jpg')
val_Carrot= glob.glob(val_dir + '/carrot/*.jpg')
val_Cauliflower= glob.glob(val_dir + '/cauliflower/*.jpg')
val_Chilli_pepper= glob.glob(val_dir + '/chilli pepper/*.jpg')
val_Corn= glob.glob(val_dir + '/corn/*.jpg')
val_Cucumber= glob.glob(val_dir + '/cucumber/*.jpg')
val_Eggplant= glob.glob(val_dir + '/eggplant/*.jpg')
val_Garlic= glob.glob(val_dir + '/garlic/*.jpg')
val_Ginger= glob.glob(val_dir + '/ginger/*.jpg')
val_Grapes= glob.glob(val_dir + '/grapes/*.jpg')
val_Jalepeno= glob.glob(val_dir + '/jalepeno/*.jpg')
val_Kiwi= glob.glob(val_dir + '/kiwi/*.jpg')
val_Lemon= glob.glob(val_dir + '/lemon/*.jpg')
val_Lettuce= glob.glob(val_dir + '/lettuce/*.jpg')
val_Mango= glob.glob(val_dir + '/mango/*.jpg')
val_Onion= glob.glob(val_dir + '/onion/*.jpg')
val_Orange= glob.glob(val_dir + '/orange/*.jpg')
val_Paprika= glob.glob(val_dir + '/paprika/*.jpg')
val_Pear= glob.glob(val_dir + '/pear/*.jpg')
val_Peas= glob.glob(val_dir + '/peas/*.jpg')
val_Pineapple= glob.glob(val_dir + '/pineapple/*.jpg')
val_Pomegranate= glob.glob(val_dir + '/pomegranate/*.jpg')
val_Potato= glob.glob(val_dir + '/potato/*.jpg')
val_Raddish= glob.glob(val_dir + '/raddish/*.jpg')
val_Soy_beans= glob.glob(val_dir + '/soy beans/*.jpg')
val_Spinach= glob.glob(val_dir + '/spinach/*.jpg')
val_Sweetcorn= glob.glob(val_dir + '/sweetcorn/*.jpg')
val_Tomato= glob.glob(val_dir + '/tomato/*.jpg')
val_Turnip= glob.glob(val_dir + '/turnip/*.jpg')
val_Watermelon= glob.glob(val_dir + '/Watermelon/*.jpg')

# %%
# # Creating dataset train, test, validation

# def create_dataframe(list_of_images):
#   data=[]
#   for image in list_of_images:
#     data.append((image, image.split('/')[-2]))

#   return pd.DataFrame(data, columns= ['images', 'label'])

# train_df = create_dataframe(train_Bean + train_Bitter_Gourd + train_Bottle_Gourd + train_Brinjal + train_Broccoli + train_Cabbage + train_Capsicum
#                             + train_Carrot + train_Cauliflower + train_Cucumber + train_Papaya + train_Potato + train_Pumpkin + train_Radish + train_Tomato)
# train_df = train_df.sample(frac=1, random_state=7).reset_index(drop=True)

# test_df = create_dataframe(test_Bean + test_Bitter_Gourd + test_Bottle_Gourd + test_Brinjal + test_Broccoli + test_Cabbage + test_Capsicum
#                             + test_Carrot + test_Cauliflower + test_Cucumber + test_Papaya + test_Potato + test_Pumpkin + test_Radish + test_Tomato)
# test_df = test_df.sample(frac=1, random_state=7).reset_index(drop=True)

# val_df = create_dataframe(val_Bean + val_Bitter_Gourd + val_Bottle_Gourd + val_Brinjal + val_Broccoli + val_Cabbage + val_Capsicum
#                             + val_Carrot + val_Cauliflower + val_Cucumber + val_Papaya + val_Potato + val_Pumpkin + val_Radish + val_Tomato)
# val_df = val_df.sample(frac=1, random_state=7).reset_index(drop=True)
